# %%
#Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#Import scikit-learn machine learning model
from sklearn.neighbors import KNeighborsClassifier, NearestNeighbors, LocalOutlierFactor

#Import scikit-learn metrics and preprocessing libraries
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
# Load the main dataframe
nfl_df = pd.read_csv('/content/sample_data/nfl_gamelogs_vegas_2017-2025_NEW (10).csv')
print(nfl_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4072 entries, 0 to 4071
# Data columns (total 91 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Season      4072 non-null   int64
#  1   Team        4072 non-null   object
#  2   Gtm         4072 non-null   float64
#  3   Week        4072 non-null   float64
#  4   Date        4072 non-null   object
#  5   Day         4072 non-null   object
#  6   Home        4072 non-null   int64
#  7   Opp_x       4072 non-null   object
#  8   Win         4072 non-null   int64
#  9   Tm_Pts      4072 non-null   float64
#  10  Opp_Pts     4072 non-null   float64
#  11  OT          4072 non-null   int64
#  12  Tm pCmp     4072 non-null   float64
#  13  Tm rAtt     4072 non-null   float64
#  14  Tm pCmp%    4072 non-null   float64
#  15  Tm pYds     4072 non-null   float64
#  16  Tm pTD      4072 non-null   float64
#  17  Tm pY/A     4072 non-null   float64
#  18  Tm pAY/A    4072 non-null   float64
#  19  Tm pRate    4072 non-null   float64
#  20  Tm Sk       4072 non-null   float64
#  21  Tm rYds     4072 non-null   float64
#  22  Tm Att.1    4072 non-null   float64
#  23  Tm rYds.1   4072 non-null   float64
#  24  Tm rTD      4072 non-null   float64
#  25  Tm rY/A     4072 non-null   float64
#  26  Tm Ply      4072 non-null   float64
#  27  Tm Tot      4072 non-null   float64
#  28  Tm Y/P      4072 non-null   float64
#  29  Tm FGA      4072 non-null   float64
#  30  Tm FGM      4072 non-null   float64
#  31  Tm XPA      4072 non-null   float64
#  32  Tm XPM      4072 non-null   float64
#  33  Tm Pnt      4072 non-null   float64
#  34  Tm PntYds   4072 non-null   float64
#  35  Tm fdPass   4072 non-null   float64
#  36  Tm fdRush   4072 non-null   float64
#  37  Tm fdPen    4072 non-null   float64
#  38  Tm 1stD     4072 non-null   float64
#  39  Tm 3DConv   4072 non-null   float64
#  40  Tm 3DAtt    4072 non-null   float64
#  41  Tm 4DConv   4072 non-null   float64
#  42  Tm 4DAtt    4072 non-null   float64
#  43  Tm Pen      4072 non-null   float64
#  44  Tm PenYds   4072 non-null   float64
#  45  Tm FL       4072 non-null   float64
#  46  Tm Int      4072 non-null   float64
#  47  Tm TO       4072 non-null   float64
#  48  Tm ToP      4072 non-null   object
#  49  Opp_pCmp    4072 non-null   float64
#  50  Opp_rAtt    4072 non-null   float64
#  51  Opp_pCmp%   4072 non-null   float64
#  52  Opp_pYds    4072 non-null   float64
#  53  Opp_pTD     4072 non-null   float64
#  54  Opp_pY/A    4072 non-null   float64
#  55  Opp_pAY/A   4072 non-null   float64
#  56  Opp_pRate   4072 non-null   float64
#  57  Opp_Sk      4072 non-null   float64
#  58  Opp_rYds    4072 non-null   float64
#  59  Opp_Att.1   4072 non-null   float64
#  60  Opp_rYds.1  4072 non-null   float64
#  61  Opp_rTD     4072 non-null   float64
#  62  Opp_rY/A    4072 non-null   float64
#  63  Opp_Ply     4072 non-null   float64
#  64  Opp_Tot     4072 non-null   float64
#  65  Opp_Y/P     4072 non-null   float64
#  66  Opp_FGA     4072 non-null   float64
#  67  Opp_FGM     4072 non-null   float64
#  68  Opp_XPA     4072 non-null   float64
#  69  Opp_XPM     4072 non-null   float64
#  70  Opp_Pnt     4072 non-null   float64
#  71  Opp_PntYds  4072 non-null   float64
#  72  Opp_fdPass  4072 non-null   float64
#  73  Opp_fdRush  4072 non-null   float64
#  74  Opp_fdPen   4072 non-null   float64
#  75  Opp_1stD    4072 non-null   float64
#  76  Opp_3DConv  4072 non-null   float64
#  77  Opp_3DAtt   4072 non-null   float64
#  78  Opp_4DConv  4072 non-null   float64
#  79  Opp_4DAtt   4072 non-null   float64
#  80  Opp_Pen     4072 non-null   float64
#  81  Opp_PenYds  4072 non-null   float64
#  82  Opp_FL      4072 non-null   float64
#  83  Opp_Int     4072 non-null   float64
#  84  Opp_TO      4072 non-null   float64
#  85  Opp_ToP     4072 non-null   object
#  86  Opp_y       4072 non-null   object
#  87  Spread      4072 non-null   float64
#  88  Total       4072 non-null   float64
#  89  Cover       4072 non-null   int64
#  90  Over        4072 non-null   int64
# dtypes: float64(78), int64(6), object(7)
# memory usage: 2.8+ MB
# None

# %%
# Add columns
nfl_df['True_Total'] = nfl_df['Tm_Pts'] + nfl_df['Opp_Pts']
nfl_df['Over'] = np.where(nfl_df['True_Total'] > nfl_df['Total'], 1, 0)
nfl_df['Under'] = np.where(nfl_df['True_Total'] < nfl_df['Total'], 1, 0)
nfl_df['Push'] = np.where(nfl_df['True_Total'] == nfl_df['Total'], 1, 0)
print(nfl_df)
for season in range(2022, 2026):
    print(nfl_df.query('Season == @season and Week == 13')['Under'].mean())
# Sort the data by Season, then by Week
nfl_df = nfl_df.sort_values(by=['Season','Week']).reset_index(drop=True)
# Out:
#       Season Team   Gtm  Week        Date  Day  Home Opp_x  Win  Tm_Pts  ...  \
# 0       2018  CRD   1.0   1.0  2018-09-09  Sun     1   WAS    0     6.0  ...
# 1       2018  CRD   2.0   2.0  2018-09-16  Sun     0   LAR    0     0.0  ...
# 2       2018  CRD   3.0   3.0  2018-09-23  Sun     1   CHI    0    14.0  ...
# 3       2018  CRD   4.0   4.0  2018-09-30  Sun     1   SEA    0    17.0  ...
# 4       2018  CRD   5.0   5.0  2018-10-07  Sun     0   SFO    1    28.0  ...
# ...      ...  ...   ...   ...         ...  ...   ...   ...  ...     ...  ...
# 4067    2025  WAS   7.0   7.0  2025-10-19  Sun     0   DAL    0    22.0  ...
# 4068    2025  WAS   8.0   8.0  2025-10-27  Mon     0   KAN    0     7.0  ...
# 4069    2025  WAS   9.0   9.0  2025-11-02  Sun     1   SEA    0    14.0  ...
# 4070    2025  WAS  10.0  10.0  2025-11-09  Sun     1   DET    0    22.0  ...
# 4071    2025  WAS  11.0  11.0  2025-11-16  Sun     0   MIA    0    13.0  ...
#
#       Opp_TO  Opp_ToP  Opp_y  Spread  Total  Cover  Over  True_Total  Under  \
# 0        1.0    38:08    WAS    -2.0   43.5      0     0        30.0      1
# 1        1.0    34:08   @LAR    13.5   43.5      0     0        34.0      1
# 2        2.0    36:21    CHI     5.5   39.0      1     0        30.0      1
# 3        0.0    31:46    SEA     3.5   40.0      1     0        37.0      1
# 4        5.0    40:12   @SFO     3.0   40.5      1     1        46.0      0
# ...      ...      ...    ...     ...    ...    ...   ...         ...    ...
# 4067     0.0    31:21   @DAL     1.0   54.0      0     1        66.0      0
# 4068     2.0    34:03   @KAN    11.0   48.0      0     0        35.0      1
# 4069     1.0    27:18    SEA     3.0   48.0      0     1        52.0      0
# 4070     0.0    32:36    DET     8.0   49.0      0     1        66.0      0
# 4071     0.0    29:51   @MIA     2.5   47.0      0     0        29.0      1
#
#       Push
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ...    ...
# 4067     0
# 4068     0
# 4069     0
# 4070     0
# 4071     0
#
# [4072 rows x 94 columns]
# 0.5333333333333333
# 0.3076923076923077
# 0.4375
# 0.3333333333333333

# %%
# Create and Evaluate a Model for NFL Totals (1 = Under, 0 = Over or Push)
# Set the dataframe
df = nfl_df.query('Home == 1').reset_index(drop=True)
# Set the features and the target variable
features = ['Spread','Total']
target = 'Under'
# Iterate over the last three seasons
for season in [2022, 2023, 2024]:
    # Display the season
    print(f'\nResults for {season}:')
    # Initialize the season aggregates
    y_preds = []
    y_trues = []
    # Iterate over the weeks in the season
    for week in range(1, 19):
        # Display the current Week
        print(f' Week {week:>14}:', end=' ')
        # Create training set
        train_df = df.query('Season < @season or (Season == @season and Week < @week)')
        # Create testing set
        test_df = df.query('Season == @season and Week == @week and True_Total != Total')
        # Create X_train, y_train, X_test, y_test
        X_train = train_df[features]
        y_train = train_df[target]
        X_test = test_df[features]
        y_test = test_df[target]
        # Set the model
        model = KNeighborsClassifier(n_neighbors=7)
        # *Create a pipeline with scaler and model
        pipe = Pipeline([('scaler', StandardScaler()), ('model', KNeighborsClassifier(n_neighbors=7))
        ])
        # Train the model
        clf = model.fit(X_train, y_train)
        # *Detect and remove novelty data from the test set
        pipe2 = Pipeline([('scaler', StandardScaler()), ('lof', LocalOutlierFactor(novelty=True))
        ])
        pipe2.fit(X_train)
        y_test_novelty = pipe2.predict(X_test)
        #print(f'/nNovelty array: {y_test_novelty}')
        # *Create a mask for novelty data
        mask = [y == 1 for y in y_test_novelty]
        #print(f'Novelty mask: {mask}')
        # *Remove the novelty games from the test set
        X_test = X_test[mask]
        y_test = y_test[mask]
        # Get the predictions
        y_pred = clf.predict(X_test)
        # *Override Week 13 model predictions to predict all Unders
        if week == 1:
          y_test = test_df[target]
          y_pred = [1] * len(y_test)
        # Get the true values
        y_true = y_test
        # Display the accuracy score for the current week
        print(f'accuracy score={accuracy_score(y_true, y_pred):.2%}')
        # Update the season aggregates
        y_preds += list(y_pred)
        y_trues += list(y_true)
    # Display the total accuracy score for the current season
    if len(y_trues) > 0:
        print(f'Season {season}: Total accuracy score={accuracy_score(y_trues, y_preds):.2%}')
        # Display the classification report for the current season
        print(f'\nClassification Report for {season}:')
        print(classification_report(y_trues, y_preds, target_names=['Over','Under']))
        # Display the confusion matrix for the current season (looking for >52 predicted on precision/under to make profit)
        cm = confusion_matrix(y_trues, y_preds)
        display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Over','Under'])
        display.plot()
        plt.grid(False)
        plt.show()
# Out:
# Results for 2022:
#  Week              1: accuracy score=68.75%
#  Week              2: accuracy score=43.75%
#  Week              3: accuracy score=73.33%
#  Week              4: accuracy score=56.25%
#  Week              5: accuracy score=50.00%
#  Week              6: accuracy score=57.14%
#  Week              7: accuracy score=69.23%
#  Week              8: accuracy score=42.86%
#  Week              9: accuracy score=23.08%
#  Week             10: accuracy score=50.00%
#  Week             11: accuracy score=50.00%
#  Week             12: accuracy score=68.75%
#  Week             13: accuracy score=53.33%
#  Week             14: accuracy score=76.92%
#  Week             15: accuracy score=31.25%
#  Week             16: accuracy score=35.71%
#  Week             17: accuracy score=57.14%
#  Week             18: accuracy score=43.75%
# Season 2022: Total accuracy score=52.83%
#
# Classification Report for 2022:
#               precision    recall  f1-score   support
#
#         Over       0.47      0.53      0.50       118
#        Under       0.58      0.53      0.56       147
#
#     accuracy                           0.53       265
#    macro avg       0.53      0.53      0.53       265
# weighted avg       0.53      0.53      0.53       265
# Results for 2023:
#  Week              1: accuracy score=80.00%
#  Week              2: accuracy score=56.25%
#  Week              3: accuracy score=56.25%
#  Week              4: accuracy score=62.50%
#  Week              5: accuracy score=85.71%
#  Week              6: accuracy score=28.57%
#  Week              7: accuracy score=61.54%
#  Week              8: accuracy score=37.50%
#  Week              9: accuracy score=50.00%
#  Week             10: accuracy score=76.92%
#  Week             11: accuracy score=50.00%
#  Week             12: accuracy score=68.75%
#  Week             13: accuracy score=53.85%
#  Week             14: accuracy score=50.00%
#  Week             15: accuracy score=57.14%
#  Week             16: accuracy score=28.57%
#  Week             17: accuracy score=50.00%
#  Week             18: accuracy score=42.86%
# Season 2023: Total accuracy score=55.51%
#
# Classification Report for 2023:
#               precision    recall  f1-score   support
#
#         Over       0.50      0.45      0.47       113
#        Under       0.59      0.64      0.61       141
#
#     accuracy                           0.56       254
#    macro avg       0.55      0.54      0.54       254
# weighted avg       0.55      0.56      0.55       254
# Results for 2024:
#  Week              1: accuracy score=46.67%
#  Week              2: accuracy score=46.67%
#  Week              3: accuracy score=26.67%
#  Week              4: accuracy score=62.50%
#  Week              5: accuracy score=50.00%
#  Week              6: accuracy score=23.08%
#  Week              7: accuracy score=60.00%
#  Week              8: accuracy score=50.00%
#  Week              9: accuracy score=73.33%
#  Week             10: accuracy score=46.15%
#  Week             11: accuracy score=42.86%
#  Week             12: accuracy score=61.54%
#  Week             13: accuracy score=56.25%
#  Week             14: accuracy score=53.85%
#  Week             15: accuracy score=33.33%
#  Week             16: accuracy score=43.75%
#  Week             17: accuracy score=75.00%
#  Week             18: accuracy score=53.33%
# Season 2024: Total accuracy score=50.57%
#
# Classification Report for 2024:
#               precision    recall  f1-score   support
#
#         Over       0.55      0.46      0.50       144
#        Under       0.47      0.56      0.51       121
#
#     accuracy                           0.51       265
#    macro avg       0.51      0.51      0.51       265
# weighted avg       0.51      0.51      0.51       265

# %%
# Get and display the neighbors for games in Season 2024, Week 18
# Iterate through the test instances and find their nearest neighbors
index = 0
for game_index, spread, total in X_test.itertuples():
    # Get the neighbor distances and indices in the dataframe
    nbr_distance = clf.kneighbors(X_test)[0][index]
    nbr_index = clf.kneighbors(X_test)[1][index]
    index += 1
    # Display the games, the distances, and the neighbors
    print(f'GAME')
    print(df.iloc[[game_index],:][['Season','Week','Team','Opp_x','Spread','Total','True_Total','Under']])
    print(f'\nNEAREST NEIGHBORS (distances={[round(value, 2) for value in nbr_distance]})')
    print(df.iloc[nbr_index,:][['Season','Week','Team','Opp_x','Spread','Total','True_Total','Under']])
    print('\n')
# Out:
# GAME
#       Season  Week Team Opp_x  Spread  Total  True_Total  Under
# 1839    2024  18.0  CRD   SFO    -4.5   43.0        71.0      0
#
# NEAREST NEIGHBORS (distances=[np.float64(0.0), np.float64(0.5), np.float64(0.5), np.float64(0.5), np.float64(0.5), np.float64(0.5), np.float64(0.5)])
#       Season  Week Team Opp_x  Spread  Total  True_Total  Under
# 879     2021   8.0  CLE   PIT    -4.5   43.0        25.0      1
# 1395    2023   6.0  JAX   IND    -4.5   43.5        57.0      0
# 1355    2023   3.0  SEA   CAR    -5.0   43.0        64.0      0
# 18      2018   2.0  CHI   SEA    -4.5   42.5        41.0      1
# 529     2020   2.0  CHI   NYG    -4.5   42.5        30.0      1
# 1781    2024  14.0  KAN   LAC    -4.0   43.0        36.0      1
# 859     2021   6.0  PIT   SEA    -5.0   43.0        43.0      0
#
#
# GAME
#       Season  Week Team Opp_x  Spread  Total  True_Total  Under
# 1840    2024  18.0  ATL   CAR    -9.0   48.0        82.0      0
#
# NEAREST NEIGHBORS (distances=[np.float64(0.5), np.float64(0.5), np.float64(0.5), np.float64(0.5), np.float64(0.71), np.float64(1.0), np.float64(1.0)])
#       Season  Week Team Opp_x  Spread  Total  True_Total  Under
# 1837    2024  17.0  TAM   CAR    -9.0   47.5        62.0      0
# 314     2019   4.0  RAM   TAM    -9.0   48.5        95.0      0
# 1769    2024  13.0  DET   CHI    -9.5   48.0        43.0      1
# 990     2021  15.0  SFO   ATL    -8.5   48.0        44.0      1
# 120     2018   8.0  PIT   CLE    -8.5   47.5        51.0      0
# 846     2021   5.0  TAM   MIA   -10.0   48.0        62.0      0
# 969     2021  14.0  KAN   LVR   -10.0   48.0        57.0      0
#
#
# GAME
#       Season  Week Team Opp_x  Spread  Total  True_Total  Under
# 1842    2024  18.0  DAL   WAS     6.5   44.0        42.0      1
#
# NEAREST NEIGHBORS (distances=[np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.5), np.float64(0.5), np.float64(0.5), np.float64(0.5)])
#       Season  Week Team Opp_x  Spread  Total  True_Total  Under
# 1052    2022   1.0  NYJ   BAL     6.5   44.0        33.0      1
# 450     2019  14.0  BUF   BAL     6.5   44.0        41.0      1
# 765     2020  17.0  PHI   WAS     6.5   44.0        34.0      1
# 445     2019  13.0  NYG   GNB     6.5   43.5        44.0      0
# 829     2021   4.0  NYJ   TEN     6.0   44.0        51.0      0
# 1357    2023   3.0  TAM   PHI     6.0   44.0        36.0      1
# 850     2021   6.0  CHI   GNB     6.0   44.0        38.0      1
#
#
# GAME
#       Season  Week Team Opp_x  Spread  Total  True_Total  Under
# 1843    2024  18.0  DEN   KAN   -10.5   40.0        38.0      1
#
# NEAREST NEIGHBORS (distances=[np.float64(0.5), np.float64(0.5), np.float64(0.5), np.float64(0.5), np.float64(0.71), np.float64(0.71), np.float64(0.71)])
#       Season  Week Team Opp_x  Spread  Total  True_Total  Under
# 191     2018  13.0  OTI   NYJ   -10.5   40.5        48.0      0
# 1494    2023  13.0  JAX   CIN   -10.0   40.0        65.0      0
# 1540    2023  16.0  KAN   LVR   -10.5   40.5        34.0      1
# 84      2018   6.0  HTX   BUF   -10.5   40.5        33.0      1
# 413     2019  11.0  MIN   DEN   -10.0   40.5        50.0      0
# 1005    2021  16.0  PHI   NYG   -10.0   40.5        44.0      0
# 1645    2024   4.0  SFO   NWE   -10.0   40.5        43.0      0
#
#
# GAME
#       Season  Week Team Opp_x  Spread  Total  True_Total  Under
# 1844    2024  18.0  DET   MIN    -2.5   56.0        40.0      1
#
# NEAREST NEIGHBORS (distances=[np.float64(0.5), np.float64(0.5), np.float64(0.5), np.float64(0.71), np.float64(1.12), np.float64(1.12), np.float64(1.12)])
#      Season  Week Team Opp_x  Spread  Total  True_Total  Under
# 840    2021   5.0  KAN   BUF    -2.5   56.5        58.0      0
# 924    2021  11.0  KAN   DAL    -2.5   56.5        28.0      1
# 645    2020  10.0  CRD   BUF    -3.0   56.0        62.0      0
# 670    2020  11.0  SEA   ARI    -3.0   56.5        49.0      1
# 78     2018   6.0  ATL   TAM    -3.0   57.0        63.0      0
# 792    2021   2.0  SDG   DAL    -3.0   55.0        37.0      1
# 651    2020  10.0  RAM   SEA    -3.0   55.0        39.0      1
#
#
# GAME
#       Season  Week Team Opp_x  Spread  Total  True_Total  Under
# 1845    2024  18.0  GNB   CHI   -10.0   41.5        46.0      0
#
# NEAREST NEIGHBORS (distances=[np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.5), np.float64(0.5), np.float64(0.71), np.float64(1.0)])
#       Season  Week Team Opp_x  Spread  Total  True_Total  Under
# 1062    2022   2.0  GNB   CHI   -10.0   41.5        37.0      1
# 803     2021   3.0  DEN   NYJ   -10.0   41.5        26.0      1
# 1127    2022   6.0  RAM   CAR   -10.0   41.5        34.0      1
# 687     2020  12.0  PIT   BAL   -10.0   42.0        33.0      1
# 986     2021  15.0  MIA   NYJ   -10.0   42.0        55.0      0
# 1677    2024   7.0  BUF   TEN    -9.5   41.0        44.0      0
# 413     2019  11.0  MIN   DEN   -10.0   40.5        50.0      0
#
#
# GAME
#       Season  Week Team Opp_x  Spread  Total  True_Total  Under
# 1846    2024  18.0  CLT   JAX    -3.5   45.0        49.0      0
#
# NEAREST NEIGHBORS (distances=[np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.5), np.float64(0.5), np.float64(0.5), np.float64(0.5)])
#       Season  Week Team Opp_x  Spread  Total  True_Total  Under
# 1387    2023   5.0  SFO   DAL    -3.5   45.0        52.0      0
# 903     2021   9.0  SFO   ARI    -3.5   45.0        48.0      0
# 880     2021   8.0  DEN   WAS    -3.5   45.0        27.0      1
# 541     2020   2.0  SEA   NWE    -4.0   45.0        65.0      0
# 299     2019   3.0  PHI   DET    -4.0   45.0        51.0      0
# 770     2021   1.0  CAR   NYJ    -4.0   45.0        33.0      1
# 889     2021   8.0  SEA   JAX    -3.5   44.5        38.0      1
#
#
# GAME
#       Season  Week Team Opp_x  Spread  Total  True_Total  Under
# 1847    2024  18.0  RAM   SEA     7.5   38.5        55.0      0
#
# NEAREST NEIGHBORS (distances=[np.float64(0.71), np.float64(0.71), np.float64(1.12), np.float64(1.12), np.float64(1.41), np.float64(1.41), np.float64(1.5)])
#       Season  Week Team Opp_x  Spread  Total  True_Total  Under
# 479     2019  15.0  WAS   PHI     7.0   38.0        64.0      0
# 838     2021   5.0  HTX   NWE     8.0   39.0        47.0      0
# 1037    2021  18.0  NYG   WAS     7.0   37.5        29.0      1
# 1668    2024   6.0  NWE   HOU     7.0   37.5        62.0      0
# 325     2019   5.0  RAI   CHI     6.5   39.5        45.0      0
# 1107    2022   5.0  CAR   SFO     6.5   39.5        52.0      0
# 63      2018   5.0  BUF   TEN     6.0   38.5        25.0      1
#
#
# GAME
#       Season  Week Team Opp_x  Spread  Total  True_Total  Under
# 1848    2024  18.0  RAI   LAC     6.5   42.0        54.0      0
#
# NEAREST NEIGHBORS (distances=[np.float64(0.5), np.float64(0.5), np.float64(0.5), np.float64(0.5), np.float64(0.71), np.float64(0.71), np.float64(0.71)])
#       Season  Week Team Opp_x  Spread  Total  True_Total  Under
# 1432    2023   8.0  WAS   PHI     6.5   42.5        69.0      0
# 343     2019   6.0  MIA   WAS     6.0   42.0        33.0      1
# 228     2018  16.0  DET   MIN     6.5   42.5        36.0      1
# 1059    2022   2.0  DAL   CIN     7.0   42.0        37.0      1
# 549     2020   3.0  DEN   TAM     6.0   42.5        38.0      1
# 412     2019  11.0  MIA   BUF     7.0   41.5        57.0      0
# 307     2019   4.0  BUF   NWE     7.0   41.5        26.0      1
#
#
# GAME
#       Season  Week Team Opp_x  Spread  Total  True_Total  Under
# 1849    2024  18.0  NWE   BUF     3.5   36.0        39.0      0
#
# NEAREST NEIGHBORS (distances=[np.float64(0.5), np.float64(0.5), np.float64(0.71), np.float64(0.71), np.float64(0.71), np.float64(0.71), np.float64(0.71)])
#       Season  Week Team Opp_x  Spread  Total  True_Total  Under
# 1665    2024   6.0  DEN   LAC     3.0   36.0        39.0      0
# 1751    2024  12.0  CLE   PIT     3.5   36.5        43.0      0
# 489     2019  16.0  NYJ   PIT     3.0   36.5        26.0      1
# 162     2018  12.0  BUF   JAX     3.0   36.5        45.0      0
# 1272    2022  16.0  RAM   DEN     3.0   36.5        65.0      0
# 1413    2023   7.0  NYG   WAS     3.0   36.5        21.0      1
# 1667    2024   6.0  RAI   PIT     3.0   36.5        45.0      0
#
#
# GAME
#       Season  Week Team Opp_x  Spread  Total  True_Total  Under
# 1850    2024  18.0  NYJ   MIA     0.0   39.0        52.0      0
#
# NEAREST NEIGHBORS (distances=[np.float64(0.0), np.float64(1.0), np.float64(1.12), np.float64(1.12), np.float64(1.41), np.float64(1.41), np.float64(1.41)])
#       Season  Week Team Opp_x  Spread  Total  True_Total  Under
# 1828    2024  17.0  JAX   TEN     0.0   39.0        33.0      1
# 1082    2022   3.0  NYG   DAL    -1.0   39.0        39.0      0
# 363     2019   8.0  BUF   PHI    -1.0   39.5        44.0      0
# 389     2019   9.0  PIT   IND    -1.0   39.5        50.0      0
# 45      2018   3.0  SEA   DAL    -1.0   40.0        37.0      1
# 308     2019   4.0  CHI   MIN     1.0   38.0        22.0      1
# 1121    2022   6.0  CHI   WAS     1.0   38.0        19.0      1
#
#
# GAME
#       Season  Week Team Opp_x  Spread  Total  True_Total  Under
# 1851    2024  18.0  PHI   NYG    -2.5   37.0        33.0      1
#
# NEAREST NEIGHBORS (distances=[np.float64(0.0), np.float64(0.0), np.float64(0.5), np.float64(0.5), np.float64(0.5), np.float64(0.5), np.float64(0.5)])
#       Season  Week Team Opp_x  Spread  Total  True_Total  Under
# 1642    2024   4.0  MIA   TEN    -2.5   37.0        43.0      0
# 309     2019   4.0  DEN   JAX    -2.5   37.0        50.0      0
# 1249    2022  15.0  CAR   PIT    -2.5   37.5        40.0      0
# 1439    2023   9.0  HTX   TAM    -2.5   36.5        76.0      0
# 1575    2023  18.0  RAI   DEN    -3.0   37.0        41.0      0
# 1301    2022  18.0  CLT   HOU    -2.5   37.5        63.0      0
# 1534    2023  15.0  OTI   HOU    -3.0   37.0        35.0      1
#
#
# GAME
#       Season  Week Team Opp_x  Spread  Total  True_Total  Under
# 1852    2024  18.0  PIT   CIN     2.5   47.5        36.0      1
#
# NEAREST NEIGHBORS (distances=[np.float64(0.0), np.float64(0.5), np.float64(0.5), np.float64(0.5), np.float64(0.5), np.float64(0.5), np.float64(0.5)])
#       Season  Week Team Opp_x  Spread  Total  True_Total  Under
# 1713    2024   9.0  GNB   DET     2.5   47.5        38.0      1
# 771     2021   1.0  CIN   MIN     3.0   47.5        51.0      0
# 166     2018  12.0  DEN   PIT     3.0   47.5        41.0      1
# 432     2019  13.0  CRD   LAR     2.5   47.0        41.0      1
# 235     2018  16.0  NYJ   GNB     3.0   47.5        82.0      0
# 316     2019   4.0  NOR   DAL     2.5   47.0        22.0      1
# 715     2020  14.0  NYG   ARI     3.0   47.5        33.0      1
#
#
# GAME
#       Season  Week Team Opp_x  Spread  Total  True_Total  Under
# 1853    2024  18.0  TAM   NOR   -14.0   45.0        46.0      0
#
# NEAREST NEIGHBORS (distances=[np.float64(0.0), np.float64(0.5), np.float64(0.5), np.float64(0.5), np.float64(1.0), np.float64(1.12), np.float64(1.12)])
#       Season  Week Team Opp_x  Spread  Total  True_Total  Under
# 251     2018  17.0  PIT   CIN   -14.0   45.0        29.0      1
# 233     2018  16.0  NWE   BUF   -13.5   45.0        36.0      1
# 1106    2022   5.0  BUF   PIT   -14.0   45.5        41.0      1
# 1786    2024  14.0  PHI   CAR   -13.5   45.0        38.0      1
# 374     2019   8.0  PIT   MIA   -14.0   44.0        41.0      1
# 1009    2021  17.0  BUF   ATL   -14.5   44.0        44.0      0
# 1472    2023  11.0  MIA   LVR   -13.5   46.0        33.0      1
#
#
# GAME
#       Season  Week Team Opp_x  Spread  Total  True_Total  Under
# 1854    2024  18.0  OTI   HOU    -1.5   36.5        37.0      0
#
# NEAREST NEIGHBORS (distances=[np.float64(0.0), np.float64(0.0), np.float64(0.71), np.float64(0.71), np.float64(0.71), np.float64(1.0), np.float64(1.12)])
#       Season  Week Team Opp_x  Spread  Total  True_Total  Under
# 1252    2022  15.0  DEN   ARI    -1.5   36.5        39.0      0
# 1244    2022  14.0  PIT   BAL    -1.5   36.5        30.0      1
# 1276    2022  16.0  NYJ   JAX    -2.0   37.0        22.0      1
# 1479    2023  12.0  DEN   CLE    -1.0   37.0        41.0      0
# 476     2019  15.0  PIT   BUF    -1.0   37.0        27.0      1
# 1439    2023   9.0  HTX   TAM    -2.5   36.5        76.0      0
# 417     2019  11.0  WAS   NYJ    -1.0   37.5        51.0      0

# %%
# Make predictions for NFL Totals (Season = 2025, Week = 13)
# Set the dataframe
df = nfl_df.query('Home == 1').reset_index(drop=True)
# Set the features and the target variable
features = ['Spread','Total']
target = 'Under'
# Set the season and the week
season = 2025
week = 13

# %%
# Create training set
train_df = df.query('Season < @season or (Season == @season and Week < @week)')
# Create X_train and y_train
X_train = train_df[features]
y_train = train_df[target]

# %%
# Two-dimensional list with upcoming game data from the home team's perspective

week13 = [['Packers @ Lions', -3.0, 48.5],
['Chiefs @ Cowboys', +3.5, 52.5],
['Bengals @ Ravens', -7.0, 51.5],
['Bears @ Eagles', -7.0, 44.5],
['Rams @ Panthers', +10.5, 45.5],
['Cardinals @ Buccaneers', -4.5, 44.5],
['Jaguars @ Titans', +6.5, 41.5],
['Saints @ Dolphins', -5.5, 42.5],
['49ers @ Browns', +4.5, 35.5],
['Falcons @ Jets', +2.5, 39.5],
['Texans @ Colts', -3.5, 44.5],
['Vikings @ Seahawks', -11.5, 41.5],
['Bills @ Steelers', +3.0, 45.5],
['Raiders @ Chargers', -9.5, 40.5],
['Broncos @ Commanbders', +5.5, 43.5],
['Giants @ Patriots', -7.5, 46.5],
]

# %%
# Create X_new dataframe from the upcoming game data
X_new = pd.DataFrame(week13, columns=['Game','Spread','Total'])

# %%
# *Create a pipeline with scaler and model
pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('model', KNeighborsClassifier(n_neighbors=7))
])

# %%
# *Train the model
clf = pipe.fit(X_train, y_train)

# %%
# *Detect and remove novelty data from the new data
lof = LocalOutlierFactor(novelty=True)
pipe2 = Pipeline([
    ('scaler', StandardScaler()),
    ('lof', LocalOutlierFactor(novelty=True))
])
#pipe2.fit(X_train.values)
pipe2.fit(X_train)
y_test_novelty = pipe2.predict(X_new[features])
#print(f'nNovelty array: {y_test_novelty}')
# Create a mask for novelty data
mask = [y == 1 for y in y_test_novelty]
# Remove the novelty games from the new dataset
X_new = X_new[mask]

# %%
# Get the predictions
y_predict = clf.predict(X_new[features])

# %%
# Add predictions to the dataframe
X_new['KNN(7)'] = y_predict
X_new['KNN(7)'] = X_new['KNN(7)'].apply(lambda x: 'Under' if x == 1 else 'Over')

# %%
# Display the dataframe with the predictions
print(f'MODEL PREDICTIONS FOR WEEK {week} OF THE {season} NFL SEASON\n')
print(X_new[['Game','Spread','Total','KNN(7)']])
# Out:
# MODEL PREDICTIONS FOR WEEK 13 OF THE 2025 NFL SEASON
#
#                       Game  Spread  Total KNN(7)
# 0          Packers @ Lions    -3.0   48.5   Over
# 1         Chiefs @ Cowboys     3.5   52.5   Over
# 2         Bengals @ Ravens    -7.0   51.5   Over
# 3           Bears @ Eagles    -7.0   44.5   Over
# 4          Rams @ Panthers    10.5   45.5   Over
# 5   Cardinals @ Buccaneers    -4.5   44.5   Over
# 6         Jaguars @ Titans     6.5   41.5   Over
# 7        Saints @ Dolphins    -5.5   42.5  Under
# 8           49ers @ Browns     4.5   35.5   Over
# 9           Falcons @ Jets     2.5   39.5  Under
# 10          Texans @ Colts    -3.5   44.5   Over
# 11      Vikings @ Seahawks   -11.5   41.5  Under
# 12        Bills @ Steelers     3.0   45.5  Under
# 13      Raiders @ Chargers    -9.5   40.5   Over
# 14   Broncos @ Commanbders     5.5   43.5  Under
# 15       Giants @ Patriots    -7.5   46.5  Under

# %%
# Week Unders in 2022, 2023, and 2024
for season in [2022, 2023, 2024]:
  week13_df = nfl_df.query('Season == @season and Week == 13')
  under_count = len(week13_df.query('Under == 1')) // 2
  print(f"Season {season}: Week 13 Under% ={under_count / 16:.2%} ({under_count} of 16)")
# Out:
# Season 2022: Week 13 Under% =50.00% (8 of 16)
# Season 2023: Week 13 Under% =25.00% (4 of 16)
# Season 2024: Week 13 Under% =43.75% (7 of 16)

# %%
# !jupyter nbconvert '/content/sample_data/NFL_predictions_tuned (2).ipynb' --to html
# Out:
# [NbConvertApp] Converting notebook /content/sample_data/NFL_predictions_tuned (2).ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 3 image(s).
# [NbConvertApp] Writing 415515 bytes to /content/sample_data/NFL_predictions_tuned (2).html
